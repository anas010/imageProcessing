# %% [markdown]
# Log

# %%
import math
import cv2 
import matplotlib.pyplot as plt

img = cv2.imread("maxresdefault.jpg", cv2.IMREAD_GRAYSCALE)

plt.imshow(img, cmap="gray")
plt.title("original image")
plt.show()

for x in range(img.shape[0]):
    for y in range(img.shape[1]):
        img[x][y] = math.log2(1+img[x][y])

plt.imshow(img, cmap="gray")
plt.title("image after processing")
plt.show()

# %% [markdown]
# exp

# %%
import math
import cv2 
import matplotlib.pyplot as plt

img = cv2.imread("maxresdefault.jpg", cv2.IMREAD_GRAYSCALE)

plt.imshow(img, cmap="gray")
plt.title("original image")
plt.show()

for x in range(img.shape[0]):
    for y in range(img.shape[1]):
        img[x][y] = math.exp(200)

plt.imshow(img, cmap="gray")
plt.title("image after processing")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-7-7c1470d03288> in <module>
#      11 for x in range(img.shape[0]):
#      12     for y in range(img.shape[1]):
# ---> 13         img[x][y] = math.exp(200)
#      14
#      15 plt.imshow(img, cmap="gray")
#
# OverflowError: Python int too large to convert to C long
